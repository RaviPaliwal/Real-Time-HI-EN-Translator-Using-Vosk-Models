# %%
import pyttsx3

def speak(text, v=None, rate=None):
    engine = pyttsx3.init()

    # Set voice if provided
    if v is not None:
        voices = engine.getProperty('voices')
        engine.setProperty('voice', voices[v].id)
        
    # Set rate if provided
    if rate is not None:
        engine.setProperty('rate', rate)
        
    engine.say(text)
    engine.runAndWait()

# %%
from googletrans import Translator
def Translate(text,lang):
    translator=Translator()
    res=translator.translate(text,dest=lang)
    return res.text

# %%
def read_audio(chunk_size):
    mic = pyaudio.PyAudio()
    stream = mic.open(format=pyaudio.paInt16,
                      channels=1,rate=16000,
                      input=True,
                      frames_per_buffer=4096)
    stream.start_stream()
    data = stream.read(chunk_size)
    mic.terminate()
    stream.stop_stream()
    stream.close()
    return data

# %%
from vosk import Model, KaldiRecognizer
import pyaudio
import json
import time


model= Model('vosk-model-small-en-in-0.4/')
recognizer = KaldiRecognizer(model,16000) 

speak("Welcome To English To Hindi Translator",0,250)
cap = pyaudio.PyAudio()
stream = cap.open(format=pyaudio.paInt16,channels=1,rate=16000,input=True,frames_per_buffer=4096)
print("Listening >>>")

while True:
    stream.start_stream()
    data = stream.read(1024)
    
    if recognizer.AcceptWaveform(data):
        result = json.loads(recognizer.Result())
        if result['text']=='':
            continue

        if result['text'] in ["bye","exit","close","end","okay thanks","ok thanks"]:
            print("Bye")
            speak("ठीक है फिर मिलते हैं",1,200)
            stream.stop_stream()
            stream.close()
            cap.terminate()
            break            
        try:
            stream.stop_stream()
            translated_text = Translate(result['text'], 'hi')
            print(f"You said: {result['text']} \nTranslated: {translated_text}")
            speak(translated_text,1)
            time.sleep(.08)
            print("Listening >>>")
        except Exception as e:
            print(f"Some Error Occured {e}")
        except KeyboardInterrupt as i:
            print("Bye")
# Out:
# Listening >>>
# You said: my name is ravi
# Translated: मेरा नाम रवि है
# Listening >>>
# You said: and from there
# Translated: और वहां से
# Listening >>>
# You said: what are you doing in my house
# Translated: तुम मेरे घर में क्या कर रहे हो
# Listening >>>
# You said: you fucking bitch
# Translated: तुम कुतिया कमबख्त
# Listening >>>
# You said: i want to us
# Translated: मैं चाहता हूं
# Listening >>>
# You said: i want to put your to around us
# Translated: मैं अपने चारों ओर आपके लिए रखना चाहता हूं
# Listening >>>
# You said: i want to cure
# Translated: मैं इलाज करना चाहता हूं
# Listening >>>
# You said: i want to for cure with either
# Translated: मैं या तो इलाज के लिए करना चाहता हूं
# Listening >>>
# You said: i want to for cure
# Translated: मैं इलाज के लिए चाहता हूं
# Listening >>>
# You said: i've gone into first year s.
# Translated: मैं प्रथम वर्ष में चला गया हूँ।
# Listening >>>
# You said: i want to work for u s
# Translated: मैं यू एस के लिए काम करना चाहता हूं
# Listening >>>
# You said: fuck my s.
# Translated: भाड़ में जाओ मेरे एस।
# Listening >>>
# You said: my a double s.
# Translated: मेरे एक डबल एस।
# Listening >>>
# You said: i want to do so because girls
# Translated: मैं ऐसा करना चाहता हूं क्योंकि लड़कियां
# Listening >>>
# You said: i want to fuck you're pests
# Translated: मैं चोदना चाहता हूँ तुम कीट हो
# Listening >>>
# You said: they want to fuck your vagina
# Translated: वे आपकी योनि को चोदना चाहते हैं
# Listening >>>
# You said: i want to for cure for china and i want to do end up with tube
# Translated: मैं चीन के लिए इलाज करना चाहता हूं और मैं ट्यूब के साथ समाप्त करना चाहता हूं
# Listening >>>
# You said: i want to fuck your vagina
# Translated: मैं तुम्हारी योनि को चोदना चाहता हूँ
# Listening >>>
# Bye
# ----------------------------------------------------------------
# KeyboardInterrupt              Traceback (most recent call last)
# Cell In[6], line 17
#      15 while True:
#      16     stream.start_stream()
# ---> 17     data = stream.read(1024)
#      19     if recognizer.AcceptWaveform(data):
#      20         result = json.loads(recognizer.Result())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pyaudio\__init__.py:570, in PyAudio.Stream.read(self, num_frames, exception_on_overflow)
#     567 if not self._is_input:
#     568     raise IOError("Not input stream",
#     569                   paCanNotReadFromAnOutputOnlyStream)
# --> 570 return pa.read_stream(self._stream, num_frames,
#     571                       exception_on_overflow)
#
# KeyboardInterrupt:

# %%
from vosk import Model, KaldiRecognizer
import pyaudio
import json
import time


model= Model('vosk-model-small-hi-0.22/')
recognizer = KaldiRecognizer(model,16000) 

speak("हिंदी ट्रांसलेटर में आपका स्वागत है",2,250)
cap = pyaudio.PyAudio()
stream = cap.open(format=pyaudio.paInt16,channels=1,rate=16000,input=True,frames_per_buffer=4096)
print("Listening >>>")
while True:
    stream.start_stream()
    data = stream.read(1024)
    
    if recognizer.AcceptWaveform(data):
        result = json.loads(recognizer.Result())
        if result['text']=='':
            continue

        if result['text'] in ["धन्यवाद","बंद करो","शुक्रिया"]:
            print("Bye")
            speak("ठीक है फिर मिलते हैं",1,200)
            stream.stop_stream()
            stream.close()
            cap.terminate()
            break            
        try:
            stream.stop_stream()
            translated_text = Translate(result['text'], 'en')
            print(f"You said: {result['text']} \nTranslated: {translated_text}")
            speak(translated_text,3)
            time.sleep(.08)
            print("Listening >>>")
        except Exception as e:
            print(f"Some Error Occured {e}")
        except KeyboardInterrupt as i:
            print("Bye")

# %%
import keyboard
import pyttsx3
import pyaudio
import json
import time
from googletrans import Translator
from vosk import Model, KaldiRecognizer
from IPython.display import clear_output


# Load speech recognition models
english_model = Model('vosk-model-small-en-in-0.4/')
hindi_model = Model('vosk-model-small-hi-0.22/')
english_recognizer = KaldiRecognizer(english_model, 16000)
hindi_recognizer = KaldiRecognizer(hindi_model, 16000)

# Start with English by default
current_recognizer = english_recognizer

# Initialize PyAudio
cap = pyaudio.PyAudio()
stream = cap.open(format=pyaudio.paInt16, channels=1, rate=16000, input=True, frames_per_buffer=4096)
speak_lang= 1

print("Listening >>>")
while True:
    if keyboard.is_pressed('h'):
        current_recognizer = hindi_recognizer  # Switch to Hindi model
        speak_lang= 0
        clear_output(wait=True)
        print("Hindi-English")
        print("सुन रहा हे >>>")
    elif keyboard.is_pressed('e'):
        current_recognizer = english_recognizer  # Switch to English model
        clear_output(wait=True)
        print("English-Hindi")
        print("Listening >>>")
        speak_lang= 1
        
    stream.start_stream()
    data = stream.read(1024)

    if current_recognizer.AcceptWaveform(data):
        result = json.loads(current_recognizer.Result())
        if result['text'] == '':
            continue

        if result['text'] in ["bye", "exit", "close", "end", "okay thanks", "ok thanks"]:
            print("Bye")
            speak("ठीक है फिर मिलते हैं", 1)
            speak("Bye!")
            break
        try:
            stream.stop_stream()
            translated_text = Translate(result['text'], 'en' if current_recognizer == hindi_recognizer else 'hi')
            print(f"You said: {result['text']} \nTranslated: {translated_text}")
            speak(translated_text, speak_lang)
            time.sleep(.08)
            print("Listening >>>")
        except Exception as e:
            print(f"Some Error Occurred {e}")
        except KeyboardInterrupt as i:
            print("Bye") 

# Close PyAudio stream
stream.stop_stream()
stream.close()
cap.terminate()

# %%
from vosk import SpkModel, KaldiRecognizer
import pyaudio
import json
import time


model= SpkModel('vosk-model-spk-0.4')
# Out:
# ----------------------------------------------------------------
# TypeError                      Traceback (most recent call last)
# Cell In[21], line 8
#       4 import time
#       7 model= SpkModel('vosk-model-spk-0.4')
# ----> 8 model = model()
#
# TypeError: 'SpkModel' object is not callable
